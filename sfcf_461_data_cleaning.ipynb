# %%
import pandas as pd

# %%
sfcf_461 = pd.read_csv('sfcf_461.csv')
sfcf_461.head()
# Out:
#     Filer_ID                                       Filer_NamL  Report_Num  \
# 0  SFO154091  Tenderloin Neighborhood Development Corporation           1
# 1    Pending                  San Francisco Opera Association           1
# 2    PENDING           MEALS ON WHEELS OF SAN FRANCISCO, INC.           0
# 3    pending               Yat-Pang Au and affilated entities           0
# 4    Pending              Yerba Buena Neighborhood Consortium           0
#
#   Committee_Type    Rpt_Date   From_Date   Thru_Date  Elect_Date  \
# 0            MDI  01/19/2017  01/01/2016  10/22/2016         NaN
# 1            MDI  11/07/2016  01/01/2016  06/30/2016  11/08/2016
# 2            MDI  11/01/2016  01/01/2016  09/24/2016  11/08/2016
# 3            MDI  12/01/2016  01/01/2016  06/30/2016  06/07/2016
# 4            MDI  07/11/2016  01/01/2016  06/30/2016  06/07/2016
#
#    tblCover_Office_Cd  tblCover_Offic_Dscr      ...      Bus_Inter BusAct_CB  \
# ...

# %%
fields = ['Payee_NamL','Filer_NamL','From_Date','Thru_Date','Elect_Date','Amount',
          'Cum_YTD','Cand_NamL','Bal_Name','Bal_Num','Bal_Juris',
          'Sup_Opp_Cd','Bus_Name']
sfcf_461 = sfcf_461[fields]
sfcf_461.head()
# Out:
#                                           Payee_NamL  \
# 0  Sierra Club, San Francisco Bay Chapter Campaig...
# 1  Yes on S, San Franciscans for the Arts & Endin...
# 2                   Dignity Fund Coalition, Yes on I
# 3                                  Jane Kim for DCCC
# 4  Affordable San Francisco For All, Yes On Propo...
#
#                                         Filer_NamL   From_Date   Thru_Date  \
# 0  Tenderloin Neighborhood Development Corporation  01/01/2016  10/22/2016
# 1                  San Francisco Opera Association  01/01/2016  06/30/2016
# 2           MEALS ON WHEELS OF SAN FRANCISCO, INC.  01/01/2016  09/24/2016
# 3               Yat-Pang Au and affilated entities  01/01/2016  06/30/2016
# 4              Yerba Buena Neighborhood Consortium  01/01/2016  06/30/2016
#
#    Elect_Date     Amount     Cum_YTD Cand_NamL  \
# 0         NaN   $2000.00   $19000.00       NaN
# 1  11/08/2016     $28.60   $39602.33       NaN
# ...

# %%
sfcf_461.to_csv('sfcf_461_cleaned.csv')
